# %%
# !conda env list
# Out:
# # conda environments:
# #
# # * -> active
# # + -> frozen
# base                     /opt/homebrew/Caskroom/miniconda/base
# h501-gutenberg       *   /opt/homebrew/Caskroom/miniconda/base/envs/h501-gutenberg
# info-501-project         /opt/homebrew/Caskroom/miniconda/base/envs/info-501-project

# %%
# So we can autoreload modules
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
from tt_gutenberg.authors import *

# %%
list_authors(by_languages=True, alias=True)
# Out:
# ['United States President (1801-1809)',
#  'Gloux, Olivier',
#  'Smith, George A. (George Albert)',
#  'Πλάτων',
#  'Serviss, Garrett P. (Garrett Putman)',
#  'Arkin, Alan Wolf',
#  'Culley, Ethel B.',
#  'Lohman, S. W.\u200f (Stanley William)',
#  'Talman, C. F. (Charles Fitzhugh)',
#  'Morton, Allen &',
#  'Leiber, Fritz Reuter',
#  'De Lobeira, Vasco',
#  'Warner, Harry Backer',
#  'Ruzic, Neil Pierce',
#  'Reigart, John Franklin',
#  'Scudo, Pierre',
#  'Calmette, Albert',
#  'Stout, Henry Rice',
#  'Eayrs, Hugh Sterling',
#  'Multzer, Marcel',
#  'Harmon, James Judson',
#  'Guin, Wyman Woods',
#  'C.L.S.C.',
#  'Gault, William C.',
#  'Griffiths, Ann Thomas',
#  'Houghton, Carolyn Wells',
#  'James, George Payne Rainsford',
#  'Robinson, Frank Malcolm',
#  'Monash, Sir John',
#  'Beaunier, Andre',
#  'Lang, Walter Andrew',
#  'Anderson, J. A. (John Alexander)',
#  'Bunyan, Johann',
#  'Seche, Leon',
#  'Fairgoer, Famed First Friday',
#  'Clothier, William Ernest',
#  'Freitag, Gustav',
#  'Jones, Raymond F. (Raymond Fisher)',
#  'Zack, Robert',
#  'Neville, Kris Ottman',
#  'Coleman, Arthur Philemon',
#  'Dominik, Hans Joachim',
#  'Barbour, R. H. (Ralph Henry)',
#  'Barr, Amelia Edith Huddleston',
#  'Archer, T. (Thomas)',
#  'Newlin, William Henry',
#  'Andersen, Hans Christian',
#  'Hay, William Delisle',
#  'Wright, George Frederick',
#  'Zeigler, Wilbur G.',
#  'Obama, Barack Hussein, II',
#  'Kirkman, F. (Francis)',
#  'Teichmann, A. (Albert)',
#  'Clifton, Mark Irvin',
#  'Deeping, George Warwick',
#  'Gozzano, Gustavo',
#  'Kauppinen, Heikki',
#  'Griffiths, Arthur George Frederick',
#  'Poe, Edgar Allen',
#  'Kahn, Otto Hermann',
#  'Bavinck, H. (Herman)',
#  'Torti, Franciscus',
#  'Ludwig, Edward William',
#  'Boccabadati, Giovanni Battista',
#  'Jones, Henry',
#  'Simak, Clifford Donald',
#  'Rocklin, Ross Louis',
#  'Borrow, George Henry',
#  'Johnson, Reginald Brimley',
#  'Browne, Thomas Alexander',
#  'Crawford, Francis Marion',
#  'Hahl, J.',
#  'Saunders, C. F. (Charles Francis)',
#  'Bennett Lumber Corporation, North Tonawanda, N.Y.',
#  'Zaehnsdorf, Joseph W.',
#  'Ericsson, Volter',
#  'Ferguson, S. C.',
#  'Allen, E. A. (Emory Adams)',
#  'Vanderem, Fernand',
#  'Fitch, Chas. (Charles)',
#  'Wilkins, William Henry',
#  'Goldsmit, Oliver',
#  'Fichte, J. G. (Johann Gottlieb)',
#  'Όμηρος',
#  'Urbanus',
#  'Shaw, M. M.',
#  'Taylor, Thomas Proclus',
#  'Stoker, Abraham',
#  'Sharkey, John Michael',
#  'Kivijarvi, Erkki',
#  'Buley, Ernest Charles',
#  'Sanborn, Franklin Benjamin',
#  'De Maupassant, Guy',
#  'Newmann, Louis',
#  'Holl, Henr. de',
#  'Marks, Winston Kinney',
#  'Balfour, Lady Frances',
#  'Waugh, Alexander Raban',
#  'Cairon, Claude Antoine Jules',
#  'Kull, George',
#  'Balazs, Alexander',
#  'Zulawski, J. (Jerzy)',
#  'Noe, Sydney Philip',
#  'Merilainen, Heikki',
#  'Soyer, A. (Alexis)',
#  'Roe, Alfred Seelye',
#  'Mackay, Helen Gansevoort (Edwards)',
#  'Protonius',
#  'Dryfoos, David M.',
#  'Sienicka, Leonia',
#  "Wilde, Oscar Fingal O'Flahertie Wills",
#  'Daudet, Louis Marie Alphonse',
#  'Dye, Charles Dudley',
#  'Cimochowski, Albert Antoine',
#  'Ruttenber, E. M. (Edward Manning)',
#  'Waring, Mary Rhodes',
#  'Jeunesse, Ernest La',
#  'Baruch, Moses',
#  'Mackenzie, A. (Alexander)',
#  'Knight, Edward Frederick',
#  'Hoisington, M. F.',
#  'Roy, Lillian Elizabeth Becker',
#  'Caius Julius Phaedrus',
#  'Oxley, James M. (James Macdonald)',
#  'Emanuel, Walter Lewis',
#  'Kinau, Johann',
#  'Jenkins, H. D. (Hester Donaldson)',
#  'Rogers, Robert Vashon',
#  'Coleman, Frederic Abernethy',
#  'Evans, Martha',
#  'Vincent, Ethel Gwendoline Moffatt, Lady',
#  'Bade, William Lemoine',
#  'Brehm, A. E. (Alfred Edmund)',
#  'Smith, White Mountain, Mrs.',
#  'Bire, Edmond',
#  'Stubbs, Harry C. (Harry Clement)',
#  'Lonnrot, Elias',
#  'Whitney, O. F.',
#  'Evans, Richard C.',
#  'Nelson, Hector William',
#  'Hayes, Charles Willard',
#  'Huch, Friedrich Georg Edmund',
#  'Jones, Alfred Ernest',
#  'Keller, Gotfryd',
#  'Storrick, William C.',
#  'Cucuel, Edouard',
#  'Harben, William Nathaniel',
#  'Mace, W. H. (William Harrison)',
#  'Fredericks, Arnold',
#  'Weinbaum, Stanley Grauman',
#  'Thomson, T. (Thomas)',
#  'Diderot, Pantophile',
#  'Keene, John Harrington',
#  'Lie, Jonas Lauritz Idemil',
#  'Bazouge',
#  'Anderson, Clair E.',
#  'Wilkuna, Kyosti',
#  'Ellis, W. T. (William Thomas)',
#  'Drake, Samuel A.',
#  'Holmes, Frederic Morell',
#  'Hepner, Adolph',
#  'Casement, Roger, Sir',
#  'Farmer, Philip Jose',
#  'Nelligan, Murray Homer',
#  'Burt, Mary Elizabeth',
#  'Donner, O. (Otto)',
#  'Young, L. D. (Lot D.)',
#  'Malot, Hector-Henri',
#  'Miller, John Alexander',
#  'Saunders, Margaret Marshall',
#  'Theilhaber-Berlin, Felix A.',
#  'Hildebrand, Sam',
#  'Elmendorf, Dwight',
#  'Wuori, M.',
#  'Russell, W. Clark (William Clark)',
#  'Riley, William',
#  'Teall, Francis Horace',
#  'Bruce, John Collingwood',
#  'Higgins, Charles A.',
#  'Crayon, Geoffrey',
#  'Bottarelli, F. (Ferdinando)',
#  'Hodgkins, W. H. (William Henry)',
#  'Leech, J. (John)',
#  'Rathbone, W. (William)',
#  'Cross, Ada Cambridge',
#  'Barron, Samuel Benton',
#  'Army and Navy Commission of the Episcopal Church',
#  'Neihardt, John Gneisenau',
#  'Janson, Christopher',
#  'Weaver, Raymond Melbourne',
#  'Pozzi-Escot, Marius Emmanuel',
#  'Ingraham, Joseph Holt',
#  'أبو العلاء المعري،',
#  'Shore, William Teignmouth',
#  'Roslin-Kalliola, Mathilda',
#  'Winship, G. P. (George Parker)',
#  'Welby, Horace',
#  'Foulis, Hugh',
#  'Urpia, Jaime Luciano Balmes',
#  'Fleming, Sanford',
#  'Clark, Jeremiah Simpson',
#  'Rauhala, Kalle Nikodemus',
#  'Dobritzhofer, Martin',
#  'Tarbell, Ida Minerva',
#  'Keene, Edward Spencer',
#  'Sheavyn, Phoebe Ann Beale',
#  'Cosquin, Emmanuel Georges',
#  'Chapelle, Howard I. (Howard Irving)',
#  'Olin, George Joyce',
#  'Phillpotts, James Surtees',
#  'Evans, Edward Everett',
#  "O'Hara, Kenneth",
#  'Shafhauser, Charles',
#  'Planck, Max Karl Ernst Ludwig',
#  'Young, Robert Franklin',
#  'Beers, Henry Augustin',
#  'Winslow, Forbes Benignus',
#  'Brady, Old King',
#  'Wright, Philip Quincy',
#  'Hutchinson, John Robert',
#  'Newman, Edward Manuel',
#  'Doede, Bill',
#  'Heer, Jakob Christoph',
#  'Manton, W. P. (Walter Porter)',
#  'Yost, Casper Salathiel',
#  'Haidar, Alaeddine',
#  'Salzmann, C. G. (Christian Gotthilf)',
#  'Bayersdorfer, Adolf',
#  'Schlemihl, Peter',
#  'Hobbs, W. H. (William Herbert)',
#  'Finnemore, J. (John)',
#  'Labaigt, Laurent',
#  'De Wit, Augusta',
#  'Stewart, Charles G.',
#  'Browne, George Lathom',
#  'Von Reumont, Alfred',
#  'Kataja, Vaino',
#  'Castren, Kaarle Alfred',
#  'Marinetti, Filippo Tommaso',
#  'Settimelli, E. (Emilio)',
#  'Malmesbury, William of',
#  "O'Donnell, Elliot",
#  'Smith, Charles Mitchell',
#  'Goddard, Frederick Bartlett',
#  'Eutropius, Flavius',
#  'Beach, Rex Ellingwood',
#  'Wood, George Warren',
#  'Ashton, Winifred',
#  'Holmes, Gordon',
#  'Sutton, Homer Lee',
#  'Luska, Sidney',
#  'Humu, Martti',
#  'Rothfeld, Otto',
#  'McIntyre, William Albert',
#  'Titchener, E. B. (Edward Bradford)',
#  'White, Thomas Ward',
#  'Faraday, M. (Michael)',
#  'Tarbell, Horace Sumner',
#  'Draper, Andrew Sloan',
#  'Emerson, Willis G. (Willis George)',
#  '劉義慶',
#  '關漢卿',
#  'Brown, Emma Elizabeth',
#  'Stanley, A. P.',
#  'Laurence, Eleanor Constance',
#  'Palmer, W. Scott (William Scott)',
#  'Pay, Committee on Railway Mail',
#  'Nansen, P. (Peter)',
#  'Burnham, Clara Louise Root',
#  '沈既濟',
#  'Holliday, Fernandez C.',
#  'Trent, A. G.',
#  'British Museum. Dept. of Manuscripts',
#  'Bleackley, Horace William',
#  'Bateson, W. (William)',
#  'Bamberger, Ludwig',
#  'Revesz, Bela',
#  'Folk, Reau Estes',
#  'Hirschberg, Julius',
#  'Lons, Hermann',
#  'Snowden, J. Ross (James Ross)',
#  'Currey, Josiah Seymour',
#  'Huxley, T. H. (Thomas Henry)',
#  'Tyrrell, Charles A. (Charles Alfred)',
#  'Hoar, Roger Sherman',
#  'Strindberg, Johan August',
#  'Webber, Harry E.',
#  'Louwerse, P.',
#  'Panton, Jane Ellen',
#  'Durnford, Hugh George',
#  'Neufeld, Carl',
#  'S., Aapo',
#  'Lewis, George W.',
#  'Hulbert, Homer Bezaleel',
#  'Verhaeren, Émile',
#  'Olmstead, Frederick Law',
#  'Sorrel, Gilbert Moxley',
#  'Flex, W. (Walter)',
#  'Vane, Harley',
#  'Westermarck, Edvard Alexander',
#  'Bloundelle-Burton, J. (John)',
#  'Lawrence, Charles Edward',
#  'Rarey, John Solomon',
#  'Pratt, E. A. (Edwin A.)',
#  'British Museum. Dept. of Greek and Roman Antiquities',
#  'Richards, Laura E.',
#  'Lawson, Henry Archibald Hertzberg',
#  'Williams, Hugh Noel',
#  'Selous, F. C. (Frederick Courteney)',
#  'Schurer, Oskar',
#  'Toller, E. (Ernst)',
#  'Hauptmann, Gerhart Johann Robert',
#  'Walpole, Sir Hugh',
#  'Ward, Lock, and Tyler',
#  'Wilson, Daniel',
#  'Darwin, Charles Robert',
#  'Miall, Louis Compton',
#  'Robertson, John Mackinnon',
#  'Helfferich, Karl Theodor',
#  'Wells, Herbert George',
#  'Boulenger, Jacques Romain',
#  'Borchardt, Georg Hermann',
#  'Sperry Gyroscope Company, inc.',
#  'Browne, Horace Baker',
#  'Becher, Johannes R. (Johannes Robert)',
#  'Janes, Lewis George',
#  'Steffen, Gustaf F. (Gustaf Fredrik)',
#  'Meakin, Annette Mary Budgett',
#  'Forsslund, Karl Erik',
#  'Blanche, August Teodor',
#  'Dodge, Natt Noyes',
#  'Dale, Mrs. J. B.',
#  'Grimm, Wilhelm Carl',
#  'Grimm, Jacob Ludwig Carl',
#  'Veron, Pierre',
#  'Sick, I. M. (Ingeborg Maria)',
#  'Story lady',
#  'Riviere, Jacques',
#  'Shipley, Arthur Everett, Sir',
#  'Webster, Cyril Bertram',
#  'Torrey, Reuben Archer',
#  'Smith, Lazzy',
#  'Legler, Henry E. (Henry Eduard)',
#  'Marston, Edward',
#  'Mitton, Geraldine Edith',
#  'Newell, M. Moyca',
#  'Troughton, A. C. (Adolphus Charles)',
#  'Paez, Ramon',
#  'Tomlinson, Everett Titsworth',
#  'Barbera, Joaquin',
#  'Macoubrey, Gulielmus',
#  'Tennyson, Alfred Lord',
#  'Morgan, Charles Langbridge',
#  'Arnoldson, Klas Pontus',
#  'Huergo, Palemon',
#  'Regis, Jul',
#  'Leatherbee, Ethel Brigham',
#  'Chambers, Robert William',
#  'Heilala, Yrjo',
#  'Hastings, Elizabeth',
#  'United States President (1789-1797)',
#  'Farrow, George Edward',
#  'Roberts, Brigham Henry',
#  'Kerslake, Thomas',
#  'Rossetti, Gabriele Pasquale Giuseppe',
#  'Lehtimaki, Konrad',
#  'Mengel, Robert M.',
#  'Tordoff, Harrison B.',
#  'Scargill, W. Pitt (William Pitt)',
#  'Dawkins, W. Boyd (William Boyd)',
#  'Sanders, W. F. L.',
#  'Kubalski, Nicolas A.',
#  'Bell, Gertrude Margaret Lowthian',
#  'Junghuhn, F. W.',
#  'Niemi, A. R. (Aukusti Robert)',
#  'Adye, John Miller, Sir',
#  'De Cuellar, Francisco',
#  'Bayley, John Robert Laurie Emilius, Sir',
#  'Gordon, William John',
#  'Bacheller, Addison Irving',
#  'Colton, Arthur Willis',
#  'Reynolds, Sir Joshua',
#  'Beard, Adelia Belle',
#  'Beard, Mary Caroline',
#  'Lafferty, Raphael Aloysius',
#  'Vale, Mark',
#  'Lang, Allen K.',
#  'Farrel, Joseph',
#  'Faccio, Rina',
#  'Weinstein, Max Bernhard',
#  'Siebe, Josefine',
#  'Middleton, Edgar C.',
#  'Kernahan, John Coulson',
#  'Goulart, Ronald Joseph',
#  'Iisalo, Osmo',
#  'Mabie, Hamilton W. (Hamilton Wright)',
#  'Wheeler, Ella',
#  'Nordhoff, Charles Bernard',
#  'Candee, Helen Churchill Hungerford',
#  'West, Wallace George',
#  'Anderson, June Millichamp Kruse',
#  'Sarvela, Heikki',
#  'Prussia (Germany). Armee. Grosser Generalstab. Kriegsgeschichtliche Abteilung Zwei',
#  'Brewster, David, Sir',
#  'Glyn, Elinor Sutherland',
#  'Hawkins, Anthony Hope',
#  'Ekblaw, Karl John Theodore',
#  'Hegel, G. W. F. (Georg Wilhelm Friedrich)',
#  'Chiniquy, Charles',
#  'Mises, Ludwig von',
#  'Hart, A. B. (Albert Bushnell)',
#  'Whewell, W. (William)',
#  'Lynch, Harry Finnis Blosse',
#  'Kurtz, Johann Heinrich',
#  'Moinaux, J. (Jules)',
#  'Ennis, William Duane',
#  'Runeberg, J. L. (Johan Ludvig)',
#  'Meyer-Meyrink, Gustav',
#  'Koning, Cornelis Johan',
#  'Gibbs, George Fort',
#  'Selvago, Alonso de Villegas',
#  'Deane, John',
#  'Blackmore, Richard Doddridge',
#  'Finck, Henry Theophilus',
#  'Herman, Otto',
#  'Owen, Jean Allan',
#  'Foster, John W. (John Watson)',
#  'Openhaimer, Frants',
#  'Mill, J. S. (John Stuart)',
#  'Seymour-Jones, Alfred',
#  'Hulme, Edward Wyndham',
#  'Davenport, Cyril James Humphries',
#  'Rahkonen, A.',
#  'Frye, James Albert',
#  'Aira, Cesar',
#  'Parker, James Gordon',
#  'Rix, Samuel Wilton',
#  'Mumford, John K.',
#  'Kyne, Peter Bernard',
#  'Schneidemuhl, Georg',
#  'Quin, Dan',
#  'Alger, A. L. (Abby Langdon)',
#  '孔子',
#  'Dircks, H. (Henry)',
#  'Reeves and Turner',
#  'York, Guaranty Trust Company of New',
#  'Austin, Mary Hunter',
#  'Lecky, Walter',
#  'Backstrom, Edvard',
#  'Lefèvre, Edwin',
#  'Morley, Christopher Darlington',
#  'Evans, John, Sir',
#  'Keary, Charles Francis',
#  'Alighieri, Dante',
#  'Mather, C. (Cotton)',
#  'Cousin, Vittorio',
#  'Jarvis, E. K.',
#  'Wood, Esther',
#  'Headley, Phineas Camp',
#  'Saul, John Cameron',
#  'Bassett, J. S. (John Spencer)',
#  'Nyrop, Christopher',
#  'Fonhus, Mikkjel',
#  'Cheesman, G. L. (George Leonard)',
#  'Wheatley, H. B. (Henry Benjamin)',
#  'Jones, Elias Henry',
#  'Mozhar Pasha',
#  'Bruckner, Martin',
#  'Jordan, D. S. (David Starr)',
#  'Driscoll, Lieutenant James R.',
#  'Goff, Harriet Newell Kneeland',
#  'Pennell, J. (Joseph)',
#  'Carter, John Franklin',
#  'Feldhaus, Franz Maria',
#  'Union Pacific Railroad Company. Passenger Dept.',
#  'Lemonnier, Antoine Louis Camille',
#  'Morgan, William Henry',
#  'Pollen, Maria Margaret La Primaudaye Mrs.',
#  'Roosevelt, Corinne',
#  'Morier, Jacob',
#  'United States. National Park Service. Office of Publications',
#  'Marcus Vitruvius Pollio',
#  'Graham, John William',
#  'Blanche, Jacques-Emile',
#  'Meeker, E. (Ezra)',
#  'Osborn, Henry F. (Henry Fairfield)',
#  'Hancock, Harrie Irving',
#  'Clarke, Rebecca Sophia',
#  'Wesselhoeft, Elizabeth Foster Pope',
#  'Mitre, Bartolome',
#  'James, G. Wharton (George Wharton)',
#  'Reed, Louis C. M.',
#  'Phillipps-Wolley, C.',
#  'Storm, Hans Theodor Woldsen',
#  'Young, F. Brett (Francis Brett)',
#  'Cressman, Robert J.',
#  'Chapin, John Carsten',
#  'Dobson, Henry Austin',
#  'Hart, William Henry',
#  'Dodgson, Charles Lutwidge',
#  'Fernow, Bernhard Eduard',
#  'Trolle, H. (Henrik) af',
#  'Miers, Henry Alexander, Sir',
#  'Bain, Francis William',
#  'Vizetelly, Francis Horace',
#  'Chaney, John Griffith',
#  'Frenkel, Romano\u200f',
#  'Ewart, Ernest Andrew',
#  'Schechter, Solomon',
#  'Gilli, Caspar',
#  'Fuller, Edwin Wiley',
#  'Johnston, R. F. (Reginald Fleming), Sir',
#  'Albertazzi',
#  'Stack, E. (Edward)',
#  'Armstrong, George Henry',
#  'Graham, John',
#  'Mills, William Wallace',
#  'Maxwell, William Babington',
#  'Lundegard, Axel',
#  'Chandler, Edmund',
#  'Julianus, Flavius Claudius',
#  'Merimee, Prosper',
#  'Valls, Rafael Puig y',
#  'Winlow, Alice Maud',
#  'Quinn, J. Henry (John Henry)',
#  'Gaboriau, Émile',
#  'Young, Stanley P.',
#  'Busk, R. H. (Rachel Harriette)',
#  'Гончаров, Иван Александрович',
#  'Parkman, F. (Francis)',
#  'Morris, E. (Edmund)',
#  'Clark, Catherine Pickens Upson',
#  'Woolsey, Sarah Chauncey',
#  'Dahlgren, F. A. (Fredrik August)',
#  'Moore, Clement C. (Clement Clarke)',
#  'Dalziel, Davison',
#  'Butler, Marion Clifford, Lady Dunboyne',
#  'Stone, C. P. (Charles P.)',
#  'Grisar, Hartmannus',
#  'Reuter, Heinrich Ludwig Christian Friedrich',
#  'Waterman, Thomas Talbot',
#  'Donner, Karl Reinhold',
#  'Snell, Roy Judson',
#  'Keble, J. (John)',
#  'Yeats, William Butler',
#  'Howard, G. E. (George Elliott)',
#  'Harris, William J.',
#  'Blafield, Karl Otto Johan',
#  'Drake, Jane Ludlow',
#  'Haygood, Atticus Greene',
#  'Slade, Christine Jope',
#  'Gibson, Watt',
#  'Pollack, Channing',
#  'Barbe, Louis A.',
#  'Maurice, Arthur B.',
#  'Peyser, Herbert Francis',
#  'Brentano, Franz Clemens',
#  'Banzole, Ottone di',
#  'Fraser-Tytler, Ann',
#  'Gunther, Agnes',
#  'Trumbull, Henry Clay',
#  'Morrow, Maud Ella',
#  'Venning, M. A.',
#  'Okenfuss, Lorenz',
#  'Cooper, H. St. John (Henry St. John)',
#  'Say, T. (Thomas)',
#  'Osler, Sir William',
#  'Windt, Harry de',
#  'Coburn, Fordyce, Mrs.',
#  'Gallon, T. (Tom)',
#  'Ingelius, A. G.',
#  'Burgess, Frank Gelett',
#  'Strutt, J. (Joseph)',
#  'Von Bonde, Cecil',
#  'Gilchrist, John Dow Fisher',
#  'Pyle, Katherine',
#  'Guyton, Bertram Edgar',
#  'Rhodes, B.',
#  'Nordstrom, Ester Blenda',
#  'Allen, Charles Grant Blairfindie',
#  'Scott, D. C. (Duncan Campbell)',
#  'Collins, Archie Frederick',
#  'Roney, Cusack Patrick, Sir',
#  'Schonherr, Karl',
#  'Spielmann, Marion Harry',
#  'Siebert, Wilbur H.',
#  'United States. Department of Defense. Department of the Army',
#  'Home, Gordon Cochrane',
#  'Becker, Tracy Chatfield',
#  'Witthaus, Rudolph August',
#  'Gosse, P. H. (Philip Henry)',
#  'Bullinger, Ethelbert William',
#  'Adams, John Gregory Bishop',
#  'Bickerstaff, Isaac',
#  'Krohn, Kaarle Leopold',
#  'Runa',
#  'Dorsey, J. Owen (James Owen)',
#  'Carey, R. Nouchette (Rosa Nouchette)',
#  'Longfellow, Henry W.',
#  'Lillie, George Arthur Howard',
#  'Rochester, Faunce',
#  'Maunder, Edward Walter',
#  'Heilbron, W. C. (William Casper)',
#  'Hodgins, John George',
#  'Parsons, S. B.',
#  'Watson, Egbert Pomeroy',
#  'Boonen, J. (Jaak)',
#  'Hillick, Mayton Clarence',
#  'Atkinson, Eleanor Stackhouse',
#  'Beck, James Montgomery',
#  'Tregarthen, John Coulson',
#  'Malatesta, Enrico',
#  'Lippincott, Leander K.',
#  'Wachenhusen, H. (Hans)',
#  'Freeman, Archdeacon (Philip)',
#  'Ward, Joseph Harvey',
#  'Mockler-Ferryman, Augustus Ferryman',
#  'Couperus, Louis Marie Anne',
#  'Elgstrom, Anna Lenah',
#  'Guerrazzi, F. D. (Francesco Domenico)',
#  'Atherton, William Henry',
#  'Garrison, W. E. (Winfred Ernest)',
#  'Foreman, Mrs. Grant',
#  'Foreman, Ulysses Grant',
#  'Judd, William J.',
#  'Case, Carleton Britton',
#  'Hedley-Peek, Francis',
#  'Latham, Robert Gordon',
#  'Gannal, Jean-Nicolas',
#  'Beyrich, Clementine (Helm), Frau',
#  'Innes, Arthur Donald',
#  'Farnham, T. J. (Thomas Jefferson)',
#  'Hankinson, Charles James',
#  'Strong, Dawsonne Melanchthon',
#  'Sorley, William Ritchie',
#  'Griffith, John William',
#  'Uhland, Johann Ludwig',
#  'Epps, Margaret T. Van',
#  'Oliver, George',
#  'Birch, S. (Samuel)',
#  'Walters, Henry Beauchamp',
#  'Crumpton, Hezekiah John',
#  'Forester, Wolstan Beaumont Charles Weld',
#  'Adams, Alton Dermont',
#  'Axon, William Edward Armytage',
#  'Paris, J. A. (John Ayrton)',
#  'Young, E. (Ernest)',
#  'Giles, Leonidas B.',
#  'Pardee, Richard Gay',
#  'Dixon, William Macneile',
#  'Wilkinson, W. C. (William Cleaver)',
#  'Johnson, Edwin Rossiter',
#  'Curwood, James-Oliver',
#  'Aria, Eliza Davis',
#  'King, W. R.',
#  'Phillips, E. F. (Everett Franklin)',
#  'Von Heyking, Elisabeth',
#  'Bragdon, Dudley Acton',
#  'Denslow, William Wallace',
#  'Enock, Charles Reginald',
#  'Wilson, H. W. (Herbert Wrigley)',
#  'Bergman, Hjalmar Fredrik Elgerus',
#  'Rowe, Reginald Percy Pfeiffer',
#  'Emerson, C. Wesley (Charles Wesley)',
#  'Kitchin, Frederick Harcourt',
#  'Hasolle, James',
#  'Monckton, H. W. (Horace Woollaston)',
#  'Bond, F. Bligh',
#  'McConn, Charles Maxwell',
#  'Bianco di Saint Jorioz, Carlo',
#  'Norris, Benjamin Franklin',
#  'Ganghofer, Ludwig Albert',
#  'Sheldon, Charles Monroe',
#  'Armitage, Ella S.',
#  'Sabbadini, Remigius',
#  'Livermore, George G.',
#  'Bates, Ernest Stuart',
#  'Crutchley, W. Caius',
#  'Ashdown, Charles H.',
#  'Rayne, H. (Henry A.)',
#  'Fox, Geo. Henry (George Henry)',
#  'Daniels, A. M.',
#  'Crockett, Samuel Rutherford',
#  'Tanner, Joseph Robson',
#  'Ford, Clyde Sinclair',
#  'Frothingham, Richard, Jr.',
#  'Giovio, Giovanni Battista, conte',
#  'Cosgrove, John Joseph',
#  'Sellar, William Young',
#  'Chittenden, Lucius Eugene',
#  'Sunden, Daniel Anton',
#  'Porchester, Lord',
#  'Jeffs, H. (Harry)',
#  'Hager, Hans Hermann Julius',
#  'Carr, E. H. (Edwin Hamlin)',
#  'Michell, Edward Blair',
#  'Froude, J. A. (James Anthony)',
#  'Hacker, Franz Xaver',
#  'Eyth, M. von (Max)',
#  'Schwindt, Petter Theodor',
#  'Robertson, Archibald Thomas',
#  'Maskell, W. M. (William Miles)',
#  'Potgieter, Everhardus Johannes',
#  'Ernst, Otto',
#  'Chambers, Ernest John',
#  'Lagus, Frithiof Henrik Bernhard',
#  'Von Saar, Ferdinand',
#  'Hill, Ashbel Fairchild',
#  'Stillman, W. J. (William James)',
#  'Maurice, Charles Edmund',
#  'Seume, J. G. (Johann Gottfried)',
#  'Krehbiel, H. E. (Henry Edward)',
#  'Willing, J. Thomson',
#  'Alcock, D.',
#  'Schwartz, Jozua Marius Willem',
#  'Gallun, Raymond Zinke',
#  'Stella',
#  'Kinneys, The',
#  'Lennox, Charlotte Ramsay',
#  'Cadwell, Charles Kirk',
#  'Rosendal, Magnus',
#  'Johnson, W. Fletcher (Willis Fletcher)',
#  'Beamont, Francis',
#  'Oliphant, Lawrence',
#  'Rand, S. T. (Silas Tertius)',
#  'Hourwich, I. A. (Isaac Aaronovich)',
#  'Boswell, C. S. (Charles Stuart)',
#  'Heimans, E.',
#  'Steward, W. Augustus',
#  'Vaughan, A. J.',
#  'Anrep-Elmpt, Reinhold, Graf',
#  'Pennell, E. R. (Elizabeth Robins)',
#  'McGrew, Paul Orman',
#  'Morris, William M.',
#  'Abernathy, Robert Harwood',
#  'Fuller, John Frederick Charles',
#  'Zangwill, I. (Israel)',
#  'Kenyon, Edith C.',
#  'Bowen, James Lorenzo',
#  'Thompson, Alexander Hamilton',
#  'Raffles, Stamford, Sir',
#  'Sayers, William Charles Berwick',
#  'Brown, James D.',
#  'Bruce, Henry Addington Bayley',
#  'Kobbe, Gustav',
#  'Da Verona, Guido',
#  'Peck, R. H.',
#  'Teinturier, Edmond',
#  'Anderson, A. T.',
#  'Wurtzburg, Charles Edward',
#  'Collins, Virgil Dewey',
#  'Gannon, Frederic Augustus',
#  'Jameson, Annie Edith',
#  'Burdick, Austin C.',
#  'Forbush, Edward H.',
#  'Haeckel, Ernst Heinrich Philipp August',
#  'Clouston, Joseph Storer',
#  'Pitollet, C. (Camille)',
#  'Harvey, Henry Edmund',
#  'Brakel, G. A.',
#  'Hume, Martin Andrew Sharp',
#  'Turnbull, A. (Alexander)',
#  'Korhos-Heikki',
#  'Robinson, William',
#  'Streicher, Johann Andreas',
#  'Gilliat, E. (Edward)',
#  'Biancolli, Louis Leopold',
#  'Metenier, Oscar',
#  'Douce, F. (Francis)',
#  'Hyvarinen, Eero',
#  'Engel, Georg Julius Leopold',
#  'Braune, Theodor Wilhelm',
#  'Kotka, Pietari',
#  'Sidwell, A. B., Mrs.',
#  'Hines, Robert W.',
#  'May, Samuel Joseph',
#  'Sandilands, J. W.',
#  'Van der Lek, Hendrik Adrianus Abraham',
#  'Curtis, Wm. E. (William Eleroy)',
#  'Scanlan, Charles M.',
#  'Macleod, Fiona',
#  'Delgado, Francisco',
#  'Meissner, C. (Carl)',
#  'Stevenson, R. L. (Robert Louis)',
#  'Arndt, Henriette Wilhelmine',
#  'Fisher, Herbert Albert Laurens',
#  'Corfield, Clara',
#  'Koskimies, Kaarlo',
#  'Barnum, Phineas Taylor',
#  'Smith, Sarah',
#  'Sutro, Alfredo',
#  'Newlin, Katharine',
#  'Vance, D. (David)',
#  'Lux, Joseph August',
#  'Sale, Florentia Wynch, Lady',
#  'Klein, Nora C.',
#  'Clifford, W. K. (William Kingdon)',
#  'Barth, C. A.',
#  'Rainsford, Markus',
#  'Costello, Ned',
#  'Engstrom, Albert',
#  'Morris, Mowbray Walter',
#  'Moore, George Edward',
#  'Deite, Carl',
#  'Fischer, E. (Eugen)',
#  'Bealby, John Thomas',
#  'Bond, Alexander Russell',
#  'Rollan, R.',
#  'Graves, F. P. (Frank Pierrepont)',
#  'Bonfadini, R. (Romualdo)',
#  'MacNeill, John Gordon Swift',
#  'Carrasco, Enrique Gil y',
#  'McGee, William John',
#  'Huntington, O. B.',
#  'Parry, Edwin Francis',
#  'Denham, Robert',
#  'Blanchard, Clarence John',
#  'Cook, Howard Willard',
#  'Jennings, John Joseph',
#  'Ruskin, J. (John)',
#  'Ealand, Charles Aubrey',
#  'Anderton, Isabella M.',
#  'Huxley, Aldous Leonard',
#  'Gillespie, Alejandro',
#  'Tait, J. S. (James Selwin)',
#  'Thayer, Martin Russell',
#  'Greenhow, Thomas Michael',
#  'Thayer, George Burton',
#  'Sydney, Margaret',
#  'Thompson, Jeannette May',
#  'Wylie, Ida Alexa Ross',
#  'Bastian, Henry Charlton',
#  'Brightwen, Eliza Elder',
#  'Comstock, Harriet Theresa Smith',
#  'Lyne, Joseph Leycester',
#  'Hall, Harry Reginald Holland',
#  'Willisius, Thomas',
#  'Wilcox, Walter D.',
#  'White, Theodore E.',
#  'Good, John Maxwell',
#  'Wynne, May',
#  'British Museum. Dept. of Coins and Medals',
#  'Pluschow, Gunther',
#  'Von Collin, Heinrich Joseph',
#  'Coey, C. A.',
#  'Forster, Brix',
#  'Souvestre, Emile',
#  'Wood-Martin, William Gregory',
#  'Richou, Gabriel Charles Marie',
#  'Lossing, Benson J. (Benson John)',
#  'Catlin, Homer D.',
#  'King, Leonard William',
#  'Cantu, Cesare',
#  'Baserga, R. (Renato)',
#  'Manrrique, Jorge',
#  'Breton, Captain Willy',
#  'Cellarius',
#  'Henderson, Daniel MacIntyre',
#  'Kisieleski, W. E. (Walter E.)',
#  'Nitsch, Helen Alice Matthews',
#  'Walsh, Robert',
#  'Gotch, John Alfred',
#  'Edwards, O. M., Sir',
#  'Maxwell, William Hamilton',
#  'Leigh, Henry Sambrooke',
#  'Peck, J. M. (John Mason)',
#  'Hunt, Caroline L.',
#  'Davis, Edwin Hamilton',
#  'Strickland, J. (Jane)',
#  'Miller, Charles C.',
#  'Wallace, Richard Horatio Edgar',
#  'Norman, C. B.',
#  'Grandgent, Charles Hall',
#  'Dyke, Harry Weston Van',
#  'Coerne, L. A. (Louis Adolphe)',
#  'Lydekker, R. (Richard)',
#  'Philippe, Ch.-L. (Charles-Louis)',
#  'Bridges, Elizabeth',
#  'Hunt, Edward Eyre',
#  'T.J. Edmonds Limited',
#  'Pritchett, Robert Taylor',
#  'Lengemann, Frederick W.',
#  'Guppy, Henry Brougham',
#  'Williams, A. W.',
#  'Jarviluoma, Artturi',
#  'Saint-Cricq, Laurent',
#  'Medicine, Royal Society of',
#  'Warrender, Julian Margaret Maitland',
#  'Reitlinger, Frédéric',
#  'Mackenzie, Alfred Robert Davidson',
#  'Tweedsmuir, John Buchan, Baron',
#  'Dunn, Byron Archibald',
#  'Arcos, Rene',
#  'Snow, Erastus',
#  'Lehigh Coal & Navigation Company',
#  'Goldberg, Dr. Isaac',
#  'Coxe, M. (William)',
#  'Holland, William Jacob',
#  'Jalava, Emil August',
#  'Ferree, Barre',
#  'Buchheimer, Louis Balthaser',
#  'Seeley, Harry Govier',
#  'Raivio, J. P.',
#  'Jackson, Arthur Mason Tippetts',
#  'Pulle, August Adriaan',
#  'Sohrmann, Johannes\u200f',
#  'Normann, Friedrich Gustav',
#  'Hayha, Johannes',
#  'Bellasis, Edward Skelton',
#  'Werner, C. Avery (Carl Avery)',
#  "Vandercook, Margaret O'Bannon Womack",
#  'Mulford, Clarence E.',
#  'Reinsch, Paul Samuel',
#  'Doliver, Mary Richardson Newman',
#  'Fry, Sheila Kaye-Smith',
#  'Kelland, Clarence B.',
#  'Medley, Julius George',
#  'Dudley, Albertus True',
#  'Harris, John, Rifleman',
#  '齊治平',
#  '蕭綺',
#  'Shuckard, W. E. (William Edward)',
#  'Herford, O. (Oliver)',
#  'Pietila, Vaino',
#  'Saintsbury, George Edward Bateman',
#  'Brummitt, Stella W.',
#  'Winter, Ernst Robert Magnus',
#  'Krag, Thomas P.',
#  'Capron, John Rand',
#  'Thayer, J. B. (James Bradley)',
#  'Morris, John Gottlieb',
#  'Lavender, David Sievert',
#  'Moodie, John',
#  'Gratacap, Louis Pope',
#  'Boulnois, Henry Percy',
#  'Brown, Karl Frederick',
#  'Duff, Edward Gordon',
#  'Presber, Hermann Otto Rudolf',
#  'Bierbaum, O. J.',
#  'Rijpma, Enneus',
#  'Gibbs, W. M.',
#  'Missions, Council of Women for Home',
#  'Wade, Mary Hazleton',
#  'Fortescue, John William, Sir',
#  'Cockerell, Charles Robert',
#  'Taura, Elfried von',
#  'Barry, Richard Hayes',
#  'Tervaskari, Mikko',
#  'Malden, H. E. (Henry Elliot)',
#  'Osborn, Henry Stafford',
#  'Price, Cornelius Edward',
#  'Lamarca, Carlos Navarro y',
#  'Von Warsberg, Alexander, Freiherr',
#  'Elliot, D. G. (Daniel Giraud)',
#  'Pemberton, Sir Max',
#  'Broke, George',
#  'Darling, C. W. (Charles William)',
#  'Aston, William George',
#  'Fritz, George',
#  'Kallio, Oskar Albin',
#  'Cane, Florence Du',
#  'Hayes, Jeff W.',
#  'Calmadenker, A.',
#  'Mill, Santiago',
#  "O'Higgins, Harvey J.",
#  'Norris, H. L.',
#  'Litsey, E. Carl (Edwin Carlile)',
#  'Wilshin, Francis F.',
#  'Moss, Edward Lawton',
#  'Club, Pleiades',
#  'Lord, Chester S.',
#  'Karinthy, Friedrich',
#  'Noyes, Henry Edward',
#  'Linskill, W. T. (William Thomas)',
#  'Patterson, J. M. (Joseph Medill)',
#  'Williamson, Charles Norris',
#  'Von Schmid, Christoph',
#  'Levy-Bruhl, Lucien',
#  'Driggs, Howard Roscoe',
#  'Chenevix, Richard',
#  'Hopkins, L. (Livingston)',
#  'Ticknor, M. G.',
#  'Podmor, F.',
#  'Biandrate, Ercole Silva, conte di',
#  'Hart, William John',
#  'Agnes, Sister Mary',
#  'Swanwick, Helena Maria Sickert',
#  'Bouterwek, F. (Friedrich)',
#  'Kennedy, John McFarland',
#  'Sardou, V. (Victorien)',
#  'Hyberdyne, Parson\u200f',
#  'Carman, William Bliss',
#  'Cawthorne, William Alexander',
#  'Smith, Elmer Boyd',
#  'Winther, Rasmus Villads Christian Ferdinand',
#  'Bull, Jakob B.',
#  'Wolbers, Julien',
#  'Forrest, Archibald Stevenson',
#  'Cawein, Madison J.',
#  'Rohlfs, Friedrich Gerhard',
#  ...]
